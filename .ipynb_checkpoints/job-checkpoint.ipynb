# %%
import pandas as pd

# %matplotlib inline
import matplotlib.pyplot as plt

jobdata = pd.read_csv("Neighborhoods_with_SNAP_Data.csv", index_col = "Neighborhood_2010_HOOD") #set neighboorhood columns as index
jobdata = jobdata[['Pop__2010','Total___Jobs_Located_in_N_hood_','SNAP_All_csv_Jobs_in__Hood__Con']]
jobdata = jobdata.head(25)
#drop low /bottom columns
# change data names + change colors
jobdata.plot(kind = 'bar', title = "Total Jobs")
